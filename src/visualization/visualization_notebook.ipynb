# %%
# Nahuatl Dictionary Data Analysis Notebook
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import re
from bs4 import BeautifulSoup

# %%
csv_file_WHP = r"C:\Users\Kevin\Github\NahuatLEX\data\raw\WHP_EarlyNahuatl_data_2024-03-26T17-22-58.csv"
WHP_df = pd.read_csv(csv_file_WHP)

csv_file_IDIEX = r"C:\Users\Kevin\Github\NahuatLEX\data\raw\IDIEZ_modern_nahuatl-all-2024-03-27T09-45-31.csv"
IDIEZ_df = pd.read_csv(csv_file_IDIEX)

# %%
# 1. Basic Data Exploration
print("Dataset Basic Information:")
print("-" * 50)
print(f"Total number of entries: {len(df)}")
print("\nColumn Types:")
print(df.dtypes)
# Out:
# Dataset Basic Information:
# --------------------------------------------------
# Total number of entries: 31806
#
# Column Types:
# Ref                                     object
# Headword                                object
# Orthographic Variants                   object
# Principal English Translation           object
# Attestations from sources in English    object
# Attestations from sources in Spanish    object
# Alonso de Molina                        object
# Frances Karttunen                       object
# Horacio Carochi / English               object
# Andrés de Olmos                         object
# Lockhart’s Nahuatl as Written           object
# themes                                  object
# Spanish Loanword                        object
# dtype: object

# %%
# 2. Missing Values Analysis
print("\nMissing Values per Column:")
missing_values = df.isnull().sum()
print(missing_values[missing_values > 0])
# Out:
# Missing Values per Column:
# Orthographic Variants                   17398
# Principal English Translation            7751
# Attestations from sources in English    25938
# Attestations from sources in Spanish    28594
# Alonso de Molina                         9291
# Frances Karttunen                       25380
# Horacio Carochi / English               31396
# Andrés de Olmos                         31700
# Lockhart’s Nahuatl as Written           30552
# themes                                  18995
# dtype: int64

# %%
# 3. Source Richness Analysis
source_columns = [
    'Attestations from sources in English', 
    'Attestations from sources in Spanish', 
    'Alonso de Molina', 
    'Frances Karttunen', 
    'Horacio Carochi / English', 
    'Andrés de Olmos', 
    'Lockhart’s Nahuatl as Written'
]

# Count of non-empty entries for each source
source_richness = {col: df[col].notna().sum() for col in source_columns}
print("\nSource Richness (Number of Non-Empty Entries):")
for source, count in source_richness.items():
    print(f"{source}: {count} entries")
# Out:
# Source Richness (Number of Non-Empty Entries):
# Attestations from sources in English: 5868 entries
# Attestations from sources in Spanish: 3212 entries
# Alonso de Molina: 22515 entries
# Frances Karttunen: 6426 entries
# Horacio Carochi / English: 410 entries
# Andrés de Olmos: 106 entries
# Lockhart’s Nahuatl as Written: 1254 entries

# %%
# 4. Themes Analysis
print("\nThemes Analysis:")
# Split themes and count their occurrences
df['themes_list'] = df['themes'].fillna('').str.split(';')
all_themes = [theme.strip() for themes in df['themes_list'] for theme in themes if theme.strip()]
theme_counts = pd.Series(all_themes).value_counts()


print("Top 10 Themes:")
print(theme_counts.head(10))
# Out:
# Themes Analysis:
# Top 10 Themes:
# Health, Sickness, Wellness, Medicine            523
# Numbers, Math                                   518
# Time, Calendar, Frequency                       454
# Anatomy                                         437
# Animals, Bugs, Insects, Reptiles, Fish, etc.    408
# Religion (Christian)                            365
# Emotions                                        365
# Behavior, Personality                           301
# Food, Eating, Cooking                           295
# Plants, Trees, Flora                            273
# Name: count, dtype: int64

# %%
# 5. Spanish Loanwords
print("\nSpanish Loanwords:")
loanword_counts = df['Spanish Loanword'].value_counts(normalize=True) * 100
print(loanword_counts)
# Out:
# Spanish Loanwords:
# Spanish Loanword
# No     95.469408
# Yes     4.530592
# Name: proportion, dtype: float64

# %%
# 6. Orthographic Variants
df['num_variants'] = df['Orthographic Variants'].fillna('').str.split(';').apply(len)
print("\nOrthographic Variants Distribution:")
print(df['num_variants'].value_counts().sort_index())
# Out:
# Orthographic Variants Distribution:
# num_variants
# 1    31797
# 2        8
# 3        1
# Name: count, dtype: int64

# %%
# Visualization Function
def create_visualizations():
    plt.figure(figsize=(20, 15))
    
    # Source Attestations
    plt.subplot(2, 2, 1)
    plt.bar(source_richness.keys(), source_richness.values())
    plt.title('Source Attestations')
    plt.xticks(rotation=45, ha='right')
    
    # Themes
    plt.subplot(2, 2, 2)
    theme_counts.head(10).plot(kind='bar')
    plt.title('Top 10 Themes')
    plt.xticks(rotation=45, ha='right')
    
    # Loanwords Pie Chart
    plt.subplot(2, 2, 3)
    loanword_counts.plot(kind='pie', autopct='%1.1f%%')
    plt.title('Spanish Loanwords')
    
    # Orthographic Variants
    plt.subplot(2, 2, 4)
    df['num_variants'].value_counts().sort_index().plot(kind='bar')
    plt.title('Orthographic Variants per Entry')
    
    plt.tight_layout()
    plt.savefig('nahuatl_dictionary_overview.png')
    plt.close()

# Run visualizations
create_visualizations()
print("\nVisualization saved as 'nahuatl_dictionary_overview.png'")
# Out:
# Visualization saved as 'nahuatl_dictionary_overview.png'

# %%
whp_refs = set()
for index, row in WHP_df.iterrows():
    ref_id = row["Ref"]
    if ref_id in whp_refs:
        print("Duplicate: "+ ref_id)
    else:
        whp_refs.add(ref_id)
        
idiez_refs = set()        
for index, row in IDIEZ_df.iterrows():
    ref_id = row["Ref"]
    if ref_id in whp_refs:
        print("Duplicate: "+ ref_id)
    else:
        idiez_refs.add(ref_id)
# Out:
# Duplicate: WHP-171916
# Duplicate: WHP-171921
# Duplicate: WHP-171922
# Duplicate: WHP-171950
# Duplicate: WHP-171954
# Duplicate: WHP-171969
# Duplicate: WHP-171978
# Duplicate: WHP-171991
# Duplicate: WHP-172003
# Duplicate: WHP-172028
# Duplicate: WHP-172033
# Duplicate: WHP-172035
# Duplicate: WHP-172041
# Duplicate: WHP-172044
# Duplicate: WHP-172066
# Duplicate: WHP-172067
# Duplicate: WHP-172140
# Duplicate: WHP-172144
# Duplicate: WHP-172145
# Duplicate: WHP-172188
# Duplicate: WHP-172225
# Duplicate: WHP-172236
# Duplicate: WHP-172286
# Duplicate: WHP-172310
# Duplicate: WHP-172337
# Duplicate: WHP-172409
# Duplicate: WHP-172435
# Duplicate: WHP-172439
# Duplicate: WHP-172449
# Duplicate: WHP-172630
# Duplicate: WHP-172637
# Duplicate: WHP-172640
# Duplicate: WHP-172644
# Duplicate: WHP-172699
# Duplicate: WHP-172834
# Duplicate: WHP-173040
# Duplicate: WHP-173046
# Duplicate: WHP-173161
# Duplicate: WHP-173189
# Duplicate: WHP-173204
# Duplicate: WHP-173244
# Duplicate: WHP-173257
# Duplicate: WHP-173276
# Duplicate: WHP-173335
# Duplicate: WHP-173513
# Duplicate: WHP-173559
# Duplicate: WHP-173583
# Duplicate: WHP-173603
# Duplicate: WHP-173630
# Duplicate: WHP-173637
# Duplicate: WHP-173807
# Duplicate: WHP-173816
# Duplicate: WHP-173912
# Duplicate: WHP-173943
# Duplicate: WHP-174035
# Duplicate: WHP-174051
# Duplicate: WHP-174273
# Duplicate: WHP-174280
# Duplicate: WHP-174294
# Duplicate: WHP-174307
# Duplicate: WHP-174337
# Duplicate: WHP-174352
# Duplicate: WHP-174360
# Duplicate: WHP-174409
# Duplicate: WHP-174411
# Duplicate: WHP-174472
# Duplicate: WHP-174478
# Duplicate: WHP-174479
# Duplicate: WHP-174492
# Duplicate: WHP-174529
# Duplicate: WHP-174543
# Duplicate: WHP-174545
# Duplicate: WHP-174594
# Duplicate: WHP-174596
# Duplicate: WHP-174640
# Duplicate: WHP-174723
# Duplicate: WHP-174727
# Duplicate: WHP-174734
# Duplicate: WHP-174808
# Duplicate: WHP-174809
# Duplicate: WHP-174844
# Duplicate: WHP-174846
# Duplicate: WHP-174903
# Duplicate: WHP-174957
# Duplicate: WHP-175103
# Duplicate: WHP-175185
# Duplicate: WHP-175232
# Duplicate: WHP-175235
# Duplicate: WHP-175262
# Duplicate: WHP-175266
# Duplicate: WHP-175279
# Duplicate: WHP-175283
# Duplicate: WHP-175296
# Duplicate: WHP-175323
# Duplicate: WHP-175325
# Duplicate: WHP-175769
# Duplicate: WHP-175779
# Duplicate: WHP-175880
# Duplicate: WHP-175920
# Duplicate: WHP-175926
# Duplicate: WHP-176006
# Duplicate: WHP-176027
# Duplicate: WHP-176031
# Duplicate: WHP-176034
# Duplicate: WHP-176035
# Duplicate: WHP-176038
# Duplicate: WHP-176040
# Duplicate: WHP-176041
# Duplicate: WHP-176043
# Duplicate: WHP-176044
# Duplicate: WHP-176056
# Duplicate: WHP-176058
# Duplicate: WHP-176059
# Duplicate: WHP-176068
# Duplicate: WHP-176071
# Duplicate: WHP-176124
# Duplicate: WHP-176130
# Duplicate: WHP-176138
# Duplicate: WHP-176177
# Duplicate: WHP-176191
# Duplicate: WHP-176208
# Duplicate: WHP-176224
# Duplicate: WHP-176332
# Duplicate: WHP-176383
# Duplicate: WHP-176400
# Duplicate: WHP-176404
# Duplicate: WHP-176436
# Duplicate: WHP-176606
# Duplicate: WHP-176623
# Duplicate: WHP-176634
# Duplicate: WHP-176865
# Duplicate: WHP-176969
# Duplicate: WHP-176981
# Duplicate: WHP-177111
# Duplicate: WHP-177120
# Duplicate: WHP-177235
# Duplicate: WHP-177282
# Duplicate: WHP-177399
# Duplicate: WHP-177467
# Duplicate: WHP-177542
# Duplicate: WHP-177605
# Duplicate: WHP-177679
# Duplicate: WHP-177743
# Duplicate: WHP-177770
# Duplicate: WHP-178104
# Duplicate: WHP-178134
# Duplicate: WHP-178162
# Duplicate: WHP-178286
# Duplicate: WHP-178314
# Duplicate: WHP-178439
# Duplicate: WHP-178445
# Duplicate: WHP-178446
# Duplicate: WHP-178449
# Duplicate: WHP-178476
# Duplicate: WHP-178537
# Duplicate: WHP-178549
# Duplicate: WHP-178552
# Duplicate: WHP-178617
# Duplicate: WHP-178621
# Duplicate: WHP-178622
# Duplicate: WHP-178687
# Duplicate: WHP-178742
# Duplicate: WHP-178748
# Duplicate: WHP-178755
# Duplicate: WHP-178806
# Duplicate: WHP-178823
# Duplicate: WHP-178842
# Duplicate: WHP-178867
# Duplicate: WHP-178868
# Duplicate: WHP-178895
# Duplicate: WHP-178909
# Duplicate: WHP-178931
# Duplicate: WHP-178944
# Duplicate: WHP-179064
# Duplicate: WHP-179066
# Duplicate: WHP-179274
# Duplicate: WHP-179630
# Duplicate: WHP-179644
# Duplicate: WHP-179651
# Duplicate: WHP-179671
# Duplicate: WHP-179754
# Duplicate: WHP-179760
# Duplicate: WHP-180151
# Duplicate: WHP-180554
# Duplicate: WHP-180860
# Duplicate: WHP-180964
# Duplicate: WHP-181483
# Duplicate: WHP-181495
# Duplicate: WHP-181827
# Duplicate: WHP-181928
# Duplicate: WHP-181936
# Duplicate: WHP-182041
# Duplicate: WHP-183004
# Duplicate: WHP-186323
# Duplicate: WHP-186345
# Duplicate: WHP-187252
# Duplicate: WHP-187369
# Duplicate: WHP-188018
# Duplicate: WHP-188204
# Duplicate: WHP-188386
# Duplicate: WHP-188782
# Duplicate: WHP-190200
# Duplicate: WHP-190516
# Duplicate: WHP-190555
# Duplicate: WHP-191031
# Duplicate: WHP-195302
# Duplicate: WHP-196448
# Duplicate: WHP-196596
# Duplicate: WHP-196687
# Duplicate: WHP-196841
# Duplicate: WHP-197082
# Duplicate: WHP-197469
# Duplicate: WHP-197477
# Duplicate: WHP-197554
# Duplicate: WHP-197590
# Duplicate: WHP-197629
# Duplicate: WHP-198232
# Duplicate: WHP-198234
# Duplicate: WHP-198246
# Duplicate: WHP-198258
# Duplicate: WHP-198284
# Duplicate: WHP-198285
# Duplicate: WHP-198300
# Duplicate: WHP-198306
# Duplicate: WHP-198316
# Duplicate: WHP-198366
# Duplicate: WHP-198370
# Duplicate: WHP-198375
# Duplicate: WHP-198394
# Duplicate: WHP-198409
# Duplicate: WHP-198442
# Duplicate: WHP-198493
# Duplicate: WHP-198497
# Duplicate: WHP-198522
# Duplicate: WHP-198528
# Duplicate: WHP-198576
# Duplicate: WHP-198598
# Duplicate: WHP-198627
# Duplicate: WHP-198638
# Duplicate: WHP-198753
# Duplicate: WHP-198910
# Duplicate: WHP-198931
# Duplicate: WHP-199136
# Duplicate: WHP-199147
# Duplicate: WHP-199197
# Duplicate: WHP-199313
# Duplicate: WHP-199502
# Duplicate: WHP-199507
# Duplicate: WHP-199529
# Duplicate: WHP-199737
# Duplicate: WHP-200575
# Duplicate: WHP-200580
# Duplicate: WHP-200729
# Duplicate: WHP-200941
# Duplicate: WHP-201779
# Duplicate: WHP-201964
# Duplicate: WHP-202109
# Duplicate: WHP-202756
# Duplicate: WHP-203257
# Duplicate: WHP-203260
# Duplicate: WHP-203264
# Duplicate: WHP-203271
# Duplicate: WHP-203337
# Duplicate: WHP-203375
# Duplicate: WHP-203418
# Duplicate: WHP-203419
# Duplicate: WHP-203433
# Duplicate: WHP-203454
# Duplicate: WHP-203459
# Duplicate: WHP-203462
# Duplicate: WHP-203484
# Duplicate: WHP-203710
# Duplicate: WHP-204043
# Duplicate: WHP-204126
# Duplicate: WHP-204281
# Duplicate: WHP-204345
# Duplicate: WHP-204626
# Duplicate: WHP-204838
# Duplicate: WHP-204860
# Duplicate: WHP-204861
# Duplicate: WHP-204906
# Duplicate: WHP-204934
# Duplicate: WHP-204951
# Duplicate: WHP-204999
# Duplicate: WHP-205014
# Duplicate: WHP-205016
# Duplicate: WHP-205019
# Duplicate: WHP-205026
# Duplicate: WHP-205253
# Duplicate: WHP-205640
# Duplicate: WHP-205713
# Duplicate: WHP-205792
# Duplicate: WHP-205794
# Duplicate: WHP-206108
# Duplicate: WHP-206268
# Duplicate: WHP-206762
# Duplicate: WHP-206833
# Duplicate: WHP-206987
# Duplicate: WHP-207136
# Duplicate: WHP-207454
# Duplicate: WHP-207776
# Duplicate: WHP-208056
# Duplicate: WHP-208294
# Duplicate: WHP-208889
# Duplicate: WHP-209093
# Duplicate: WHP-209105
# Duplicate: WHP-209118
# Duplicate: WHP-209488
# Duplicate: WHP-209596
# Duplicate: WHP-209705
# Duplicate: WHP-210284
# Duplicate: WHP-210615
